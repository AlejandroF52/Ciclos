# %% [markdown]
# # Clase 1

# %% [markdown]
# #### En esta  clase vamos a ver codigo relacionado con Python

# %%
t = 4
T = "4"
e = "cuatro"
# Impresión de variables
print("El número es: ", t)
# Out:
# 4
